# %%
import pandas as pd
import numpy as np
from PIL import Image
from PIL import ImageOps
import PIL
import torch, torchvision
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from ansim_dataset import ansimDataset, create_circular_mask
# from convolution_lstm import encoderConvLSTM, decoderConvLSTM
from ConvLSTM import ConvLSTM
import random
import math
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
from torchvision import datasets, models, transforms
import time
import os
import scipy.ndimage

# %%
# %env CUDA_VISIBLE_DEVICES=3
# Out:
# env: CUDA_VISIBLE_DEVICES=3

# %%
img_path = '/home/rliu/ansim/data/data/JPEGImages/'
img_list_csv = '/home/rliu/github/ansim/img_list.csv'
train_csv = '/home/rliu/github/ansim/train.csv'
test_csv = '/home/rliu/github/ansim/test.csv'
output_path = '/home/rliu/ansim/models/very_first.pt'

# %%
mask = create_circular_mask(128,128)

testset = ansimDataset(img_list_csv = img_list_csv, seq_csv = test_csv, root_dir = img_path, step=20, random_rotate = True, mask = mask, transform=None)
testloader = torch.utils.data.DataLoader(testset,
                                             batch_size=1, shuffle=True,
                                             num_workers=1)

# %%
model = torch.load('/home/rliu/ansim/models/0005.weights').cuda()

# %%
dataiter = iter(testloader)
images = dataiter.next()
data_split = torch.split(images, int(images.shape[1]/2), dim=1)
inputs = data_split[0]
target = data_split[1]

inputs, target = inputs.cuda(), target.cuda()

_, _, predicted = model(inputs)

# %%
predicted = predicted[0,:,0,:,:].cpu().detach().numpy()

# %%
target = target[0,:,0,:,:].cpu().detach().numpy()

# %%
inputs = inputs[0,:,0,:,:].cpu().detach().numpy()

# %%
predicted.shape
# Out:
# (10, 128, 128)

# %%
target.shape
# Out:
# (10, 128, 128)

# %%
def imshow(img):
#     img = img * 0.1909 + 0.3019     # unnormalize
#     npimg = img.numpy()
    plt.imshow(np.transpose(img, (1, 2, 0)))

# %%
plt.imshow(scipy.ndimage.zoom(predicted.reshape(1280,128).transpose(), 2, order=0))

# %%
fig = plt.figure(figsize=(18, 16))
ax = fig.add_subplot(111)
ax.imshow(scipy.ndimage.zoom(inputs.reshape(1280,128).transpose(), 2, order=0), interpolation='nearest',shape=(128,1280))

# %%
fig = plt.figure(figsize=(18, 16))
ax = fig.add_subplot(111)
ax.imshow(scipy.ndimage.zoom(target.reshape(1280,128).transpose(), 2, order=0), interpolation='nearest',shape=(128,1280))

# %%
fig = plt.figure(figsize=(18, 16))
ax = fig.add_subplot(111)
ax.imshow(scipy.ndimage.zoom(predicted.reshape(1280,128).transpose(), 2, order=0), interpolation='nearest',shape=(128,1280))

# %%
np.transpose(predicted,(1,2,0))
# Out:
# array([[[-1.330217  , -1.296545  , -1.3687427 , ..., -1.7917354 ,
#          -1.8429928 , -1.8864679 ],
#         [-0.02763954,  0.1233238 ,  0.1711483 , ...,  0.30234003,
#           0.32154596,  0.33853433],
#         [-0.2997485 , -0.17911068, -0.15388045, ..., -0.16392413,
#          -0.1706442 , -0.17817888],
#         ...,
#         [-0.24961874, -0.13182017, -0.11011711, ..., -0.10884979,
#          -0.11167732, -0.1141611 ],
#         [-0.10833117,  0.08307108,  0.14413273, ...,  0.2817713 ,
#           0.29901993,  0.3148767 ],
#         [-1.2363911 , -1.2240765 , -1.2478404 , ..., -1.3453059 ,
#          -1.355427  , -1.3646863 ]],
#
#        [[-0.02229872,  0.14079416,  0.16786054, ...,  0.35640275,
#           0.39300472,  0.42828232],
#         [-0.0060927 ,  0.20033222,  0.22928771, ...,  0.3032843 ,
#           0.30631155,  0.30686152],
#         [-0.26863846, -0.10058537, -0.0876576 , ..., -0.1395764 ,
#          -0.14598909, -0.1487433 ],
#         ...,
# ...
